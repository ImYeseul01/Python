# %% [markdown]
# pandas 스터디

# %%
import pandas as pd

# %%
df = pandas.DataFrame(
  {"a" : [4 ,5, 6],
  "b" : [7, 8, 9],
  "c" : [10, 11, 12]},
  index = [1, 2, 3])

# %%
df
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
df[df.a>5]
# Out:
#    a  b   c
# 3  6  9  12

# %%
df.drop_duplicates()
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
df.loc[1,['a','b']]
# Out:
# a    4
# b    7
# Name: 1, dtype: int64

# %%
df.loc[2]
# Out:
# a     5
# b     8
# c    11
# Name: 2, dtype: int64

# %%
df = pd.DataFrame(
  [[4, 7, 10],
  [5, 8, 11],
  [6, 9, 12]],
  index=[1, 2, 3],
  columns=['a', 'b', 'c'])

  df
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
df = pd.DataFrame(
  {"a" : [4 ,5, 6, 6],
  "b" : [7, 8, 9, 9],
  "c" : [10, 11, 12, 12]},
  index = pd.MultiIndex.from_tuples(
  [('d',1),('d',2),('e',1),('e',2)],
  names=['n','v']))

df
# Out:
#      a  b   c
# n v
# d 1  4  7  10
#   2  5  8  11
# e 1  6  9  12
#   2  6  9  12

# %%
df.head(2)
# Out:
#      a  b   c
# n v
# d 1  4  7  10
#   2  5  8  11

# %%
df=df.drop_duplicates()
df.tail(2)
# Out:
#      a  b   c
# n v
# d 2  5  8  11
# e 1  6  9  12

# %%
df.sample(frac=0.5)
# Out:
#      a  b   c
# n v
# e 1  6  9  12
# d 2  5  8  11

# %%
df.iloc[1:2]
# Out:
#      a  b   c
# n v
# d 2  5  8  11

# %%
df
# Out:
#      a  b   c
# n v
# d 1  4  7  10
#   2  5  8  11
# e 1  6  9  12

# %%
df.nsmallest(1, 'c')
# Out:
#      a  b   c
# n v
# d 1  4  7  10

# %%
df[['a','c']]
# Out:
#      a   c
# n v
# d 1  4  10
#   2  5  11
# e 1  6  12

# %%
df
# Out:
#      a  b   c
# n v
# d 1  4  7  10
#   2  5  8  11
# e 1  6  9  12

# %%
df.loc[[('d',1),('e',2)],['a','b','c']]
# Out:
#      a  b   c
# n v
# d 1  4  7  10
# e 2  6  9  12

# %%
df.loc[('d',2)]
# Out:
# a     4
# b     7
# c    10
# Name: (d, 1), dtype: int64

# %%
df['c']
# Out:
# n  v
# d  1    10
#    2    11
# e  2    12
# Name: c, dtype: int64
